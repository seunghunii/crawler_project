# %%
import pandas as pd
import numpy as np
from glob import glob
import re
import datetime

# %%
dirr = "C:/Users/shic/Desktop/crawler_project/data_save/kb_land/final/"
list_files = glob(dirr+'*.csv')
list_files
# Out:
# ['C:/Users/shic/Desktop/crawler_project/data_save/kb_land/final\\매매가격_변화율.csv',
#  'C:/Users/shic/Desktop/crawler_project/data_save/kb_land/final\\매매가격_지수.csv',
#  'C:/Users/shic/Desktop/crawler_project/data_save/kb_land/final\\매매시장_매매거래.csv',
#  'C:/Users/shic/Desktop/crawler_project/data_save/kb_land/final\\매매시장_매수우위.csv']

# %%
meme_diff = pd.read_csv(list_files[0])
meme_jisu = pd.read_csv(list_files[1])

# %%
meme_diff['rate_d_conv'] = pd.to_datetime(meme_diff['rate_d'],format='%Y,%m,%d')
meme_jisu['jisu_d_conv'] = pd.to_datetime(meme_jisu['jisu_d'],format='%Y,%m,%d')

# %%
meme_jisu['jisu_d'][0].isocalendar()[1]
# Out:
# 9

# %%
tmp_diff = [k.isocalendar()[1] for k in meme_jisu['jisu_d']]
tmp_diff
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-436c1eee0ff2> in <module>
# ----> 1 tmp_diff = [k.isocalendar()[1] for k in meme_jisu['jisu_d']]
#       2 tmp_diff
#
# <ipython-input-93-436c1eee0ff2> in <listcomp>(.0)
# ----> 1 tmp_diff = [k.isocalendar()[1] for k in meme_jisu['jisu_d']]
#       2 tmp_diff
#
# pandas\_libs\tslibs\nattype.pyx in pandas._libs.tslibs.nattype._make_error_func.f()
#
# ValueError: NaTType does not support isocalendar

# %%
meme_jisu['jisu_d'].unique()
# Out:
# array(['2011-02-28T00:00:00.000000000', '2011-03-07T00:00:00.000000000',
#        '2011-03-14T00:00:00.000000000', '2011-03-21T00:00:00.000000000',
#        '2011-03-28T00:00:00.000000000', '2011-04-04T00:00:00.000000000',
#        '2011-04-11T00:00:00.000000000', '2011-04-18T00:00:00.000000000',
#        '2011-04-25T00:00:00.000000000', '2011-05-02T00:00:00.000000000',
#        '2011-05-09T00:00:00.000000000', '2011-05-16T00:00:00.000000000',
#        '2011-05-23T00:00:00.000000000', '2011-05-30T00:00:00.000000000',
#        '2011-06-06T00:00:00.000000000', '2011-06-13T00:00:00.000000000',
#        '2011-06-20T00:00:00.000000000', '2011-06-27T00:00:00.000000000',
#        '2011-07-04T00:00:00.000000000', '2011-07-11T00:00:00.000000000',
#        '2011-07-18T00:00:00.000000000', '2011-07-25T00:00:00.000000000',
#        '2011-08-01T00:00:00.000000000', '2011-08-08T00:00:00.000000000',
#        '2011-08-15T00:00:00.000000000', '2011-08-22T00:00:00.000000000',
# ...
