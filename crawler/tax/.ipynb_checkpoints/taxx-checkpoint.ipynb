# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import re
from time import sleep
import requests
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한국은행경제통계시스템 api
# 통합재정수지 - 재산세 코드 028Y009 - A010102
# 조세징수액 - 종합부동산세 코드 085Y050 - G2AAH

# %% [markdown]
# ## 통합재정수지 - 재산세

# %%
urll = 'http://ecos.bok.or.kr/api/StatisticSearch/CDFMS9PHEOO7QULTNTI4/xml/kr/1/10000/028Y009/MM/2010/2021/A010102'
a = requests.get(urll)
a
# Out:
# <Response [200]>

# %%
xml = BeautifulSoup(a.text,'xml')
raw = xml.find_all('row')

# %%
data_list = []
time_list = []
for itter in raw:
    data_list.append(itter.find('DATA_VALUE').text)
    time_list.append(itter.find('TIME').text)

# %%
df = pd.DataFrame({
    'time' : time_list,
    'taxx' : data_list
})
df['time'] = pd.to_datetime(df['time'],format='%Y%m')
df['taxx'] = df['taxx'].astype(int)
df
# Out:
#           time   taxx
# 0   2010-01-01    387
# 1   2010-02-01   1214
# 2   2010-03-01   1871
# 3   2010-04-01   2372
# 4   2010-05-01   2944
# ..         ...    ...
# 127 2020-08-01  12098
# 128 2020-09-01  14011
# 129 2020-10-01  16284
# 130 2020-11-01  18128
# 131 2020-12-01  22735
#
# [132 rows x 2 columns]

# %%
plt.figure(figsize=(18,8))
sns.lineplot(x=df['time'].dt.year,y='taxx',data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='time', ylabel='taxx'>

# %% [markdown]
# ## 통합재정수지 - 종합부동산세

# %%
urll = 'http://ecos.bok.or.kr/api/StatisticSearch/CDFMS9PHEOO7QULTNTI4/xml/kr/1/100000/085Y050/YY/2000/2021/G2AAH'
b = requests.get(urll)
b
# Out:
# <Response [200]>

# %%
 b.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><StatisticSearch>\n<list_total_count>15</list_total_count>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2005</TIME>\n<DATA_VALUE>4413</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2006</TIME>\n<DATA_VALUE>13275</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2007</TIME>\n<DATA_VALUE>24143</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2008</TIME>\n<DATA_VALUE>21299</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2009</TIME>\n<DATA_VALUE>12071</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2010</TIME>\n<DATA_VALUE>10289</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2011</TIME>\n<DATA_VALUE>11019</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2012</TIME>\n<DATA_VALUE>11311</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2013</TIME>\n<DATA_VALUE>12243</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2014</TIME>\n<DATA_VALUE>13072</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM_NAME2> </ITEM_NAME2>\n<ITEM_CODE3> </ITEM_CODE3>\n<ITEM_NAME3> </ITEM_NAME3>\n<UNIT_NAME>억원 </UNIT_NAME>\n<TIME>2015</TIME>\n<DATA_VALUE>13990</DATA_VALUE>\n</row>\n<row>\n<STAT_CODE>085Y050</STAT_CODE>\n<STAT_NAME>6.4.2 조세징수액</STAT_NAME>\n<ITEM_CODE1>G2AAH</ITEM_CODE1>\n<ITEM_NAME1>종합부동산세</ITEM_NAME1>\n<ITEM_CODE2> </ITEM_CODE2>\n<ITEM ...

# %%
xml = BeautifulSoup(b.text,'xml')
raw = xml.find_all('row')

# %%
data_list = []
time_list = []
for itter in raw:
    data_list.append(itter.find('DATA_VALUE').text)
    time_list.append(itter.find('TIME').text)

# %%
df_jongbu = pd.DataFrame({
    'time' : time_list,
    'taxx' : data_list
})
df_jongbu
# Out:
#     time   taxx
# 0   2005   4413
# 1   2006  13275
# 2   2007  24143
# 3   2008  21299
# 4   2009  12071
# 5   2010  10289
# 6   2011  11019
# 7   2012  11311
# 8   2013  12243
# 9   2014  13072
# 10  2015  13990
# 11  2016  12939
# 12  2017  16520
# 13  2018  18728
# 14  2019  26713
