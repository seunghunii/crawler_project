# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
data_dir = 'C:/Users/shic/Desktop/crawler_project/data_save/courtauction'

# %%
df_seoul = pd.read_csv(data_dir+'/df_seoul.csv').iloc[:,1:]

# %%
df_seoul
# Out:
#                물건용도 물건용도.1  경매건수  매각건수    감정가(단위:원)   매각가(단위:원)    매각율  \
# 0               아파트    아파트    37    12  12090000000  9936844999  32.4%
# 1        단독주택,다가구주택   단독주택     0     0            0           0     0%
# 2        단독주택,다가구주택  다가구주택     0     0            0           0     0%
# 3        단독주택,다가구주택     겸용     2     2   4952561830  5508000001   100%
# 4        단독주택,다가구주택     소계     2     2   4952561830  5508000001   100%
# ...             ...    ...   ...   ...          ...         ...    ...
# 65545  상가,오피스텔,근린시설   근린시설     0     0            0           0     0%
# 65546  상가,오피스텔,근린시설     겸용     2     1    120000000    47100000    50%
# 65547  상가,오피스텔,근린시설     소계     3     2    285000000   205980000  66.7%
# 65548            기타     기타     0     0            0           0     0%
# 65549            전체     전체    11     6   1272184980  1066060000  54.5%
#
#          매각가율   sido sigu  year  month
# 0       82.2%  서울특별시  강남구  2010      1
# ...
