# %%
import pandas as pd

# %%
dirr = 'C:/Users/shic/Desktop/shinhan_simon/google_drive/crawler_data/court/'

# %%
d1 = pd.read_csv(dirr+'df_court_0803.csv')
d2 = pd.read_csv(dirr+'df_court_for_december.csv')
# Out:
# C:\Users\shic\anaconda3\envs\simon_env\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (2,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
d1.shape
# Out:
# (543734, 12)

# %%
d2.shape
# Out:
# (46044, 12)

# %%
d1
# Out:
#             물건용도_대분류 물건용도_소분류 경매건수 매각건수          감정가          매각가    매각율  \
# 0                아파트      아파트   44   23  17950000000  14819658220  52.3%
# 1         단독주택,다가구주택     단독주택    1    0            0            0     0%
# 2         단독주택,다가구주택    다가구주택    1    0            0            0     0%
# 3         단독주택,다가구주택       겸용    1    0            0            0     0%
# 4         단독주택,다가구주택       소계    3    0            0            0     0%
# ...              ...      ...  ...  ...          ...          ...    ...
# 543729  상가,오피스텔,근린시설     근린시설    0    0            0            0     0%
# 543730  상가,오피스텔,근린시설       겸용    1    1   1306947040    698000000   100%
# 543731  상가,오피스텔,근린시설       소계    4    4   1849947040   1048300000   100%
# 543732            기타       기타    0    0            0            0     0%
# 543733            전체       전체  107   52  21494304594  14842609497  48.6%
#
#          매각가율      시/도 시/군/구  시기_년  시기_월
# 0       82.6%    서울특별시   강남구     9     0
# ...

# %%
d2
# Out:
#            물건용도_대분류 물건용도_소분류 경매건수 매각건수          감정가          매각가    매각율  \
# 0               아파트      아파트   66   21  29300000000  21535494600  31.8%
# 1        단독주택,다가구주택     단독주택    3    1   1229730990   1069999900  33.3%
# 2        단독주택,다가구주택    다가구주택    0    0            0            0     0%
# 3        단독주택,다가구주택       겸용    0    0            0            0     0%
# 4        단독주택,다가구주택       소계    3    1   1229730990   1069999900  33.3%
# ...             ...      ...  ...  ...          ...          ...    ...
# 46039  상가,오피스텔,근린시설     근린시설    0    0            0            0     0%
# 46040  상가,오피스텔,근린시설       겸용    1    0            0            0     0%
# 46041  상가,오피스텔,근린시설       소계    1    0            0            0     0%
# 46042            기타       기타    0    0            0            0     0%
# 46043            전체       전체  104   38  10097413320   7718671200  36.5%
#
#         매각가율      시/도 시/군/구  시기_년  시기_월
# 0      73.5%    서울특별시   강남구     9    11
# ...

# %%
df = pd.concat([d1,d2],axis=0)
df.reset_index(drop=True,inplace=True)
df
# Out:
#             물건용도_대분류 물건용도_소분류 경매건수 매각건수          감정가          매각가    매각율  \
# 0                아파트      아파트   44   23  17950000000  14819658220  52.3%
# 1         단독주택,다가구주택     단독주택    1    0            0            0     0%
# 2         단독주택,다가구주택    다가구주택    1    0            0            0     0%
# 3         단독주택,다가구주택       겸용    1    0            0            0     0%
# 4         단독주택,다가구주택       소계    3    0            0            0     0%
# ...              ...      ...  ...  ...          ...          ...    ...
# 589773  상가,오피스텔,근린시설     근린시설    0    0            0            0     0%
# 589774  상가,오피스텔,근린시설       겸용    1    0            0            0     0%
# 589775  상가,오피스텔,근린시설       소계    1    0            0            0     0%
# 589776            기타       기타    0    0            0            0     0%
# 589777            전체       전체  104   38  10097413320   7718671200  36.5%
#
#          매각가율      시/도 시/군/구  시기_년  시기_월
# 0       82.6%    서울특별시   강남구     9     0
# ...

# %%
df.to_csv(dirr + 'df_court_bind.csv',index=False)
