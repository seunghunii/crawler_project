# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
data_dir = 'C:/Users/shic/Desktop/crawler_project/data_save/courtauction'

# %%
df = pd.read_csv(data_dir + '/df_bind.csv')
# Out:
# C:\Users\shic\anaconda3\envs\simon_env\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0          물건용도 물건용도.1 경매건수 매각건수    감정가(단위:원)    매각가(단위:원)  \
# 0                0           아파트    아파트   37   12  12090000000   9936844999
# 1                1    단독주택,다가구주택   단독주택    0    0            0            0
# 2                2    단독주택,다가구주택  다가구주택    0    0            0            0
# 3                3    단독주택,다가구주택     겸용    2    2   4952561830   5508000001
# 4                4    단독주택,다가구주택     소계    2    2   4952561830   5508000001
# ...            ...           ...    ...  ...  ...          ...          ...
# 202555          14  상가,오피스텔,근린시설   근린시설   12    2    948000000    700000000
# 202556          15  상가,오피스텔,근린시설     겸용    8    4   2396131500   2102100756
# 202557          16  상가,오피스텔,근린시설     소계   43    8   3582131500   3042200756
# 202558          17            기타     기타    0    0            0            0
# 202559          18            전체     전체  103   49  24852037780  21966526265
#
#           매각율    매각가율   sido sigu  year  month
# 0       32.4%   82.2%  서울특별시  강남구  2010      1
# 1          0%      0%  서울특별시  강남구  2010      1
# 2          0%      0%  서울특별시  강남구  2010      1
# 3        100%  111.2%  서울특별시  강남구  2010      1
# 4        100%  111.2%  서울특별시  강남구  2010      1
# ...       ...     ...    ...  ...   ...    ...
# 202555  16.7%   73.8%    경기도  화성시  2021      6
# 202556    50%   87.7%    경기도  화성시  2021      6
# 202557  18.6%   84.9%    경기도  화성시  2021      6
# 202558     0%      0%    경기도  화성시  2021      6
# 202559  47.6%   88.4%    경기도  화성시  2021      6
#
# [202560 rows x 13 columns]
