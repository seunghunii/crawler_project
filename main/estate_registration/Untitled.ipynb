# %%
import pandas as pd

# %%
dirr = 'C:/Users/rsh15/Google Drive/crawler_data/estate_registration/'

# %%
df = pd.read_csv(dirr + 'auction_count_by_age.csv')
df
# Out:
#        admin_regn1_name bdata_age sex admin_regn2_name  tot  admin_regn1_cd  \
# 0                 서울특별시   19세~29세  여자              강남구    1              11
# 1                 서울특별시   30세~39세  여자              강남구    4              11
# 2                 서울특별시   50세~59세  여자              강남구    4              11
# 3                 서울특별시    70세 이상  여자              강남구    1              11
# 4                 서울특별시   40세~49세  남자              강남구    2              11
# ...                 ...       ...  ..              ...  ...             ...
# 544212             경상남도   40세~49세  남자          창원시 의창구    1              48
# 544213             경상남도   50세~59세  남자          창원시 진해구    1              48
# 544214          제주특별자치도   50세~59세  여자              제주시    1              50
# 544215          제주특별자치도   19세~29세  남자              제주시    1              50
# 544216          제주특별자치도   50세~59세  남자              제주시    1              50
#
# ...

# %%
df_uni = df[['admin_regn1_name','admin_regn2_name',
             'bdata_age','sex','res_date','search_real_cls']].drop_duplicates()
df_uni
# Out:
#        admin_regn1_name admin_regn2_name bdata_age sex res_date  \
# 0                 서울특별시              강남구   19세~29세  여자  2012-01
# 1                 서울특별시              강남구   30세~39세  여자  2012-01
# 2                 서울특별시              강남구   50세~59세  여자  2012-01
# 3                 서울특별시              강남구    70세 이상  여자  2012-01
# 4                 서울특별시              강남구   40세~49세  남자  2012-01
# ...                 ...              ...       ...  ..      ...
# 544192             경상남도              고성군   30세~39세  남자  2021-07
# 544196             경상남도              밀양시   30세~39세  남자  2021-07
# 544201             경상남도              진주시   40세~49세  여자  2021-07
# 544202             경상남도              진주시   60세~69세  여자  2021-07
# 544203             경상남도              진주시   30세~39세  남자  2021-07
#
#         search_real_cls
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# ...

# %%
df_list = []
for region in df_uni.iterrows():
    print(region[1][''])
# Out:
# ['서울특별시' '부산광역시' '대구광역시' '인천광역시' '광주광역시' '대전광역시' '울산광역시' '세종특별자치시' '경기도'
#  '강원도' '충청북도' '충청남도' '전라북도' '전라남도' '경상북도' '경상남도' '제주특별자치도']
# ['강남구' '강동구' '강북구' '강서구' '관악구' '광진구' '구로구' '금천구' '노원구' '도봉구' '동대문구' '동작구'
#  '마포구' '서대문구' '서초구' '성동구' '성북구' '송파구' '양천구' '영등포구' '용산구' '은평구' '종로구' '중구'
#  '중랑구' '금정구' '기장군' '남구' '동구' '동래구' '부산진구' '북구' '사상구' '사하구' '서구' '수영구'
#  '연제구' '영도구' '해운대구' '달서구' '달성군' '수성구' '강화군' '계양구' '남동구' '미추홀구' '부평구' '연수구'
#  '옹진군' '광산구' '대덕구' '유성구' '울주군' '@' '가평군' '고양시 덕양구' '고양시 일산동구' '고양시 일산서구'
#  '과천시' '광명시' '광주시' '구리시' '군포시' '김포시' '남양주시' '동두천시' '부천시' '성남시 분당구'
#  '성남시 수정구' '성남시 중원구' '수원시 권선구' '수원시 영통구' '수원시 장안구' '수원시 팔달구' '시흥시'
#  '안산시 단원구' '안산시 상록구' '안성시' '안양시 동안구' '안양시 만안구' '양주시' '양평군' '여주시' '연천군'
#  '오산시' '용인시 기흥구' '용인시 수지구' '용인시 처인구' '의왕시' '의정부시' '이천시' '파주시' '평택시' '포천시'
#  '하남시' '화성시' '강릉시' '고성군' '동해시' '삼척시' '속초시' '양구군' '양양군' '영월군' '원주시' '인제군'
#  '정선군' '철원군' '춘천시' '태백시' '평창군' '홍천군' '화천군' '횡성군' '괴산군' '단양군' '보은군' '영동군'
# ...
