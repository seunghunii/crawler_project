# %%
import pandas as pd
from glob import glob

# %%
dirr = 'C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new/'

# %%
list_files = glob(dirr+'*.csv')
list_files
# Out:
# ['C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new\\부동산시장_소비심리지수_20210824151628.csv',
#  'C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new\\주택매매시장_소비심리지수_20210824143933.csv',
#  'C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new\\주택시장_소비심리지수_20210824143844.csv',
#  'C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new\\주택전세시장_소비심리지수_20210824144008.csv',
#  'C:/Users/rsh15/Desktop/seunghuni/인턴/crawler_data/estate_trend/new\\토지시장_소비심리지수_20210824143909.csv']

# %%
pd.read_csv(list_files[0],encoding='CP949')
# Out:
#    시도별(1)   시도별(2) 2012. 01 2012. 02 2012. 03 2012. 04 2012. 05 2012. 06  \
# 0      전국       소계    109.1    114.6    111.4    110.5    109.5     99.0
# 1     수도권       소계    104.4    109.1    105.1    104.5    104.4     93.1
# 2     수도권    서울특별시    106.3    109.9    104.5    104.0    105.0     93.0
# 3     수도권    인천광역시     99.6    106.6    105.4    103.7    100.4     90.4
# 4     수도권      경기도    104.3    109.2    105.3    105.0    105.0     93.6
# 5    비수도권       소계    114.9    121.0    119.1    117.9    115.6    106.3
# 6    비수도권    부산광역시    109.8    115.8    115.4    112.5    110.6     99.9
# 7    비수도권    대구광역시    121.8    127.4    124.0    122.6    122.1    114.2
# 8    비수도권    광주광역시    121.0    126.1    124.5    124.6    119.6    111.8
# 9    비수도권    대전광역시     97.9    103.3     97.0     94.2     97.9     93.4
# 10   비수도권    울산광역시    121.4    130.9    131.6    137.3    125.3    109.7
# 11   비수도권  세종특별자치시        -        -        -        -        -        -
# ...
