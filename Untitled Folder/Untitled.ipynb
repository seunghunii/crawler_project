# %%
import numpy as np
import pandas as pd
import dtw
import warnings
import scipy
warnings.filterwarnings('ignore')

# %%
dirr = 'C:/Users/shic/Desktop/shinhan_simon/google_drive/crawler_data/'
#dirr = 'C:/Users/rsh15/Google Drive/crawler_data/'

# %%
kbland = pd.read_csv(dirr + 'kbland/RAA_KB부동산매매전세가격지수_수정_유승훈.csv')
court  = pd.read_csv(dirr + 'court/RAA_법원경매통계_유승훈.csv')

# %%
court
# Out:
#         ACTN_THNG_PRPS_BCLAS_CODE  ACTN_THNG_PRPS_SCLAS_CODE SIDONM SIGNGU_NM  \
# 0                               7                          0    강원도       강릉시
# 1                               7                          0    강원도       강릉시
# 2                               7                          0    강원도       강릉시
# 3                               7                          0    강원도       강릉시
# 4                               7                          0    강원도       강릉시
# ...                           ...                        ...    ...       ...
# 579020                          0                          0   충청북도       충주시
# 579021                          0                          0   충청북도       충주시
# 579022                          0                          0   충청북도       충주시
# 579023                          0                          0   충청북도       충주시
# 579024                          0                          0   충청북도       충주시
#
#         BASE_YM  ACTN_ITMN  DISP_ITMN    ESTM_PRICE    DISP_PRICE  DISP_RT  \
# 0        201201        0.0        0.0  0.000000e+00  0.000000e+00    0.000
# 1        201202        0.0        0.0  0.000000e+00  0.000000e+00    0.000
# 2        201203        0.0        0.0  0.000000e+00  0.000000e+00    0.000
# 3        201204        0.0        0.0  0.000000e+00  0.000000e+00    0.000
# 4        201205        0.0        0.0  0.000000e+00  0.000000e+00    0.000
# ...         ...        ...        ...           ...           ...      ...
# 579020   202103      100.0       42.0  3.637935e+09  2.291155e+09    0.420
# 579021   202104       59.0       29.0  3.974281e+09  2.642680e+09    0.492
# 579022   202105       56.0       20.0  6.770141e+09  3.441992e+09    0.357
# 579023   202106       30.0        9.0  7.105793e+08  5.893763e+08    0.300
# 579024   202107       54.0       18.0  2.226684e+09  1.483120e+09    0.333
#
#         DISP_VLUE_RT
# 0              0.000
# 1              0.000
# 2              0.000
# 3              0.000
# 4              0.000
# ...              ...
# 579020         0.630
# 579021         0.665
# 579022         0.508
# 579023         0.829
# 579024         0.666
#
# [579025 rows x 11 columns]

# %%
kb_kangwon = kbland[kbland['SIDONM']=='강원도'].groupby('BASE_YM',as_index=False)[
    ['TRDE_PRICE_CHNG_RT','TRDE_PRICE_INDX','TRDE_DEAL_INDX','BUY_ADVAN_INDX']].mean()
kb_kangwon
# Out:
#      BASE_YM  TRDE_PRICE_CHNG_RT  TRDE_PRICE_INDX  TRDE_DEAL_INDX  \
# 0     201102            0.250000        76.133333        0.000000
# 1     201103            0.292500        76.683333        0.000000
# 2     201104            0.404167        77.900000        0.000000
# 3     201105            0.338000        79.153333        0.000000
# 4     201106            0.305000        80.441667        0.000000
# ..       ...                 ...              ...             ...
# 120   202102            0.283333        98.288889       33.866667
# 121   202103            0.201333        99.080000       29.580000
# 122   202104            0.152500       100.025000       22.500000
# 123   202105            0.208667       100.786667       23.340000
# 124   202106            0.438333       102.425000       32.050000
#
#      BUY_ADVAN_INDX
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.000000
# ..              ...
# 120       90.166667
# 121       85.880000
# 122       91.700000
# 123      101.960000
# 124      106.975000
#
# [125 rows x 5 columns]

# %%
kb_kangwon['BASE_YM'] = pd.to_datetime(kb_kangwon['BASE_YM'],format='%Y%m')
kb_kangwon = kb_kangwon[kb_kangwon['BASE_YM']>'2011-12-31']

# %%
court_kangwon = court[court['SIDONM']=='강원도'].groupby('BASE_YM',as_index=False).agg({
    'ACTN_ITMN':'sum','DISP_ITMN':'sum',
    'ESTM_PRICE':'sum','DISP_PRICE':'sum',
    'DISP_RT':'mean','DISP_VLUE_RT':'mean'
})
court_kangwon
# Out:
#      BASE_YM  ACTN_ITMN  DISP_ITMN    ESTM_PRICE    DISP_PRICE   DISP_RT  \
# 0     201201     2392.0      722.0  1.116931e+11  8.302414e+10  0.172500
# 1     201202     2048.0      787.0  1.155371e+11  6.739759e+10  0.230158
# 2     201203     1811.0      596.0  6.614119e+10  4.951793e+10  0.171073
# 3     201204     2376.0      755.0  1.572864e+11  9.177437e+10  0.194801
# 4     201205     1614.0      519.0  9.762974e+10  5.691454e+10  0.160056
# ..       ...        ...        ...           ...           ...       ...
# 110   202103     1731.0      549.0  1.221584e+11  8.491629e+10  0.186319
# 111   202104     1271.0      419.0  8.032934e+10  5.881976e+10  0.182813
# 112   202105     1416.0      487.0  1.336631e+11  8.791992e+10  0.186754
# 113   202106     1180.0      460.0  1.102551e+11  7.768416e+10  0.225216
# 114   202107     1069.0      422.0  8.328751e+10  5.433441e+10  0.193556
#
#      DISP_VLUE_RT
# 0        0.304175
# 1        0.334827
# 2        0.318924
# 3        0.350474
# 4        0.275567
# ..            ...
# 110      0.295833
# 111      0.280623
# 112      0.289728
# 113      0.341980
# 114      0.252795
#
# [115 rows x 7 columns]

# %%
court_kangwon['BASE_YM'] = pd.to_datetime(court_kangwon['BASE_YM'],format='%Y%m')
court_kangwon = court_kangwon[court_kangwon['BASE_YM']<'2021-07-01']

# %%
kb_cols = kb_kangwon.columns.values.tolist()
court_cols = court_kangwon.columns.values.tolist()

# %%
print(kb_cols)
print(court_cols)
# Out:
# ['BASE_YM', 'TRDE_PRICE_CHNG_RT', 'TRDE_PRICE_INDX', 'TRDE_DEAL_INDX', 'BUY_ADVAN_INDX']
# ['BASE_YM', 'ACTN_ITMN', 'DISP_ITMN', 'ESTM_PRICE', 'DISP_PRICE', 'DISP_RT', 'DISP_VLUE_RT']

# %%
np.corrcoef([kb_kangwon[kb_cols[4]].values,
             court_kangwon[court_cols[6]].values])
# Out:
# array([[1.        , 0.08161258],
#        [0.08161258, 1.        ]])

# %%
corr_result = []
for kbb in kb_cols[1:]:
    for courtt in court_cols[1:]:
        np_coef = np.corrcoef([kb_kangwon[kbb].values,
                            court_kangwon[courtt].values])
        corr_result.append(pd.DataFrame({
            'kb_cols' : kbb,
            'court_cols' : courtt,
            'corr':np_coef[0,1]
        },index=[0]))

# %%
pd.concat(corr_result)
# Out:
#               kb_cols    court_cols      corr
# 0  TRDE_PRICE_CHNG_RT     ACTN_ITMN  0.041264
# 0  TRDE_PRICE_CHNG_RT     DISP_ITMN  0.175649
# 0  TRDE_PRICE_CHNG_RT    ESTM_PRICE  0.171508
# 0  TRDE_PRICE_CHNG_RT    DISP_PRICE  0.339161
# 0  TRDE_PRICE_CHNG_RT       DISP_RT  0.310180
# 0  TRDE_PRICE_CHNG_RT  DISP_VLUE_RT  0.333953
# 0     TRDE_PRICE_INDX     ACTN_ITMN -0.784839
# 0     TRDE_PRICE_INDX     DISP_ITMN -0.677456
# 0     TRDE_PRICE_INDX    ESTM_PRICE -0.385364
# 0     TRDE_PRICE_INDX    DISP_PRICE -0.339086
# 0     TRDE_PRICE_INDX       DISP_RT -0.035729
# 0     TRDE_PRICE_INDX  DISP_VLUE_RT -0.187954
# 0      TRDE_DEAL_INDX     ACTN_ITMN -0.066109
# 0      TRDE_DEAL_INDX     DISP_ITMN  0.020170
# 0      TRDE_DEAL_INDX    ESTM_PRICE  0.046878
# 0      TRDE_DEAL_INDX    DISP_PRICE  0.130837
# 0      TRDE_DEAL_INDX       DISP_RT  0.207231
# 0      TRDE_DEAL_INDX  DISP_VLUE_RT  0.025683
# 0      BUY_ADVAN_INDX     ACTN_ITMN -0.285620
# 0      BUY_ADVAN_INDX     DISP_ITMN -0.120306
# 0      BUY_ADVAN_INDX    ESTM_PRICE -0.035600
# 0      BUY_ADVAN_INDX    DISP_PRICE  0.093312
# 0      BUY_ADVAN_INDX       DISP_RT  0.254722
# 0      BUY_ADVAN_INDX  DISP_VLUE_RT  0.081613

# %%
stats.pearsonr([kb_kangwon[kbb].values,
                            court_kangwon[courtt].values])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-849f113a7ad6> in <module>
# ----> 1 stats.pearsonr([kb_kangwon[kbb].values,
#       2                             court_kangwon[courtt].values])
#
# NameError: name 'stats' is not defined

# %%
scipy.stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-d2e1a58f1dd7> in <module>
# ----> 1 scipy.stats
#
# AttributeError: module 'scipy' has no attribute 'stats'
